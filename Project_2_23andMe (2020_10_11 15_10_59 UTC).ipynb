# %%
import os
import numpy as np
import pandas as pd

# %%
def proc_23me(tsv_filename):
    """Used to quickly parse custom 23 and Me formatted files
    
    File is tab-delimited that is specially formatted from 
    23andMe raw data. The four columns that exist in the data
    are:
        1. CHR: Which contig the SNP is on
        2. POS: Which base pair position the SNP was observed
        3. dbSNP_ID: A unique id for known SNPS
        4. ALLELE: the resulting SNP allele
    
    Args:
        tsv_filename (str): /path/to/special/23andMe
    
    Returns:
        (pd.DataFrame): formatted DataFrame
    """
    # Because of the funky format, custom header is needed
    cols = 'CHR POS dbSNP_ID ALLELE'.split()
    return pd.read_csv(tsv_filename, sep = '\t', names = cols)

# %%
def proc_PharmGKB(PharmGKB_filename):
    """Utility function for parsing dbSNP data from PharmGKB.
    
    File is tab-delimited and the first column is uniquely identifying
    id for each annotation. Thus, it is used as the resultant 
    DataFrame's index column
    
    Args:
        PharmGKB_filename (str): /path/to/PharmGKB.tsv
    
    Returns:
        (pd.DataFrame): formatted DataFrame
    """
    return pd.read_csv(PharmGKB_filename, sep = '\t', header=0)

# %%
def fix_missing_quotes(filename, prefix = 'fixed_'):
    """One-off function to correct unbalanced quotes in files
    by just removing all quotes (as they aren't needed anyways).
    
    Args:
        filename (str): /path/to/filename
        prefix (str): what the fixed filename should start with (default: 'fixed_')
    
    Returns:
        (str): name of fixed file
    """
    dirname, basename = os.path.split(os.path.abspath(filename))
    new_file = os.path.join(dirname, prefix+basename)
    with open(new_file, 'w') as fixed:
        for line in open(filename):
            line = line.strip()\
                .replace('\"', '')
            print(line, file = fixed)
    return new_file

# %%
# Ingest the data
pgkb = proc_PharmGKB(fix_missing_quotes('var_drug_ann.tsv'))
t3am = proc_23me('23andme_v5_hg19_ref.txt')

# %%
# Filter out pertinent items before the merge
predicate = np.logical_and(
    pgkb['Phenotype Category'] == 'efficacy', 
    pgkb['Significance'] == 'yes'
)
pgkb_w_predicate = pgkb[predicate]

# %%
# What I want my finished product columns to be
merge_cols = 'Annotation_ID dbSNP_ID GENE_SYMBOL DRUG_NAME PMID PHENOTYPE_CATEGORY SIGNIFICANCE NOTES SENTENCE ALLELE_PharmGKB ALLELE_23andme'.split()

# %%
# Handle the custom data cleaning here
# because PharmGKB has different column names
# compared to 23andMe. This could have been
# handled in the ingest step, but I always like
# keeping the data as close to stock for as long
# as possible.
merged = pd.DataFrame(
    pgkb_w_predicate.merge(t3am, 
        left_on='Variant', 
        right_on = 'dbSNP_ID')\
    .loc[:,[
        'Annotation ID',
        'dbSNP_ID', 
        'Gene',
        'Chemical', 
        'PMID', 
        'Phenotype Category', 
        'Significance', 
        'Notes', 
        'Sentence', 
        'Alleles', 
        'ALLELE']]
)

# Finalize the "look" of the DataFrame
merged.columns = merge_cols

# %%
print(f'Number of intersected SNPS: {merged.shape[0]}')
# Out:
# Number of intersected SNPS: 1157

# %%
# Uncomment to write to file (if that's your thing)
# merged.drop('Annotation_ID', 1).to_csv('23andme_PharmGKB_map.tsv', sep = '\t')

# %% [markdown]
# ---
# # Extra Credit

# %%
# Don't mess up a good thing
ec_merged = merged.copy(deep=True)

# %% [markdown]
# ## Sanity check
# If any entry in this dataset has a comman (,) in the
# `DRUG_NAME` and `GENE_SYMBOL` columns, this means they will
# become multiple entries tied to the same `Annotation_ID`.
#
# Therefore, I want to identify some of those rows in the data.

# %%
# Generate the boolean mask
multi_genes = ec_merged.GENE_SYMBOL.str.contains(',')
mutli_drugs = ec_merged.DRUG_NAME.str.contains(',')

# %%
san_check = ec_merged[(multi_genes) & (mutli_drugs)].sample(1).squeeze()

# %%
annot_id = san_check.Annotation_ID
print(f'Annotation ID: {annot_id}')
genes = san_check.GENE_SYMBOL.split(',')
len_genes = len(genes)
print(f'Gene Symbols (n = {len_genes}):')
print('\t' + '\n\t'.join(genes))
drugs = san_check.DRUG_NAME.split(',')
len_drugs = len(drugs)
print(f'Drug Names (n = {len_drugs}):')
print('\t'+ '\n\t'.join(drugs))
# Out:
# Annotation ID: 981501391
# Gene Symbols (n = 2):
# 	IFNL3 (PA134952671)
# 	IFNL4 (PA166049147)
# Drug Names (n = 3):
# 	peginterferon alfa-2a (PA164749390)
# 	peginterferon alfa-2b (PA164784024)
# 	ribavirin (PA451241)

# %% [markdown]
# Now, to turn our head on the sanity check, these drug/gene combos
# may affect multiple annotations. So, we want to
# quickly find out how many `dbSNP_ID`s are associated with this drug/gene
# combo.

# %%
# Get the boolean masks ready
goi = genes[0]
doi = drugs[0]
gene_found = ec_merged.GENE_SYMBOL.str.contains(goi, regex=False)
drug_found = ec_merged.DRUG_NAME.str.contains(doi, regex=False)

# Look at the data
combos = ec_merged[(gene_found) & (drug_found)]
print(f'Gene of interest:       {goi}')
print(f'Drug of interest:       {doi}')
print(f'Number of associations: {combos.shape[0]}')
display(combos)
# Out:
# Gene of interest:       IFNL3 (PA134952671)
# Drug of interest:       peginterferon alfa-2a (PA164749390)
# Number of associations: 60
#      Annotation_ID    dbSNP_ID                              GENE_SYMBOL  \
# 234      769248374  rs12980275                      IFNL3 (PA134952671)
# 235     1444843603  rs12980275                      IFNL3 (PA134952671)
# 237     1444705811  rs12980275                      IFNL3 (PA134952671)
# 238     1449164615  rs12980275                      IFNL3 (PA134952671)
# 239      769248378   rs8099917                      IFNL3 (PA134952671)
# 241      981479632   rs8099917                      IFNL3 (PA134952671)
# 242      981479639   rs8099917                      IFNL3 (PA134952671)
# 243      981481554   rs8099917                      IFNL3 (PA134952671)
# 244      981481567   rs8099917                      IFNL3 (PA134952671)
# 245      981483529   rs8099917                      IFNL3 (PA134952671)
# 248      981481560   rs8099917                      IFNL3 (PA134952671)
# 250      981481540   rs8099917                      IFNL3 (PA134952671)
# 252      981934519   rs8099917                      IFNL3 (PA134952671)
# 259     1444704847   rs8099917                      IFNL3 (PA134952671)
# 264     1445296808   rs8099917                      IFNL3 (PA134952671)
# 268     1444665876   rs8099917                      IFNL3 (PA134952671)
# 270     1444843486   rs8099917                      IFNL3 (PA134952671)
# 271     1444843578   rs8099917                      IFNL3 (PA134952671)
# 272     1444843741   rs8099917                      IFNL3 (PA134952671)
# 274     1444705817   rs8099917                      IFNL3 (PA134952671)
# 275     1447682270   rs8099917                      IFNL3 (PA134952671)
# 280     1447676770   rs8099917                      IFNL3 (PA134952671)
# 281     1447676959   rs8099917                      IFNL3 (PA134952671)
# 283     1450810272   rs8099917  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 303      769250998  rs28416813                      IFNL3 (PA134952671)
# 304      981477606  rs28416813                      IFNL3 (PA134952671)
# 306      769251002  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 307      981481472  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 308      981501391  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 309      981478958  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 310      981478966  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 311      981483535  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 312      981481534  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 314      981481546  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 315      981478976  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 316      981934499  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 317      982031571  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 322     1448107049  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 323     1184985914  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 324     1448107024  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 325     1444704894  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 328     1444843627  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 329     1444843642  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 333     1444706170  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 336     1444665865  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 341     1444705804  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 342     1444706036  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 343     1447676759  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 344     1444706780  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 348     1446904199  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 349     1447676885  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 350     1447682452  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 352     1447676829  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 354     1449164359  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 355     1450810253  rs12979860  IFNL3 (PA134952671),IFNL4 (PA166049147)
# 448      981477583   rs8105790                      IFNL3 (PA134952671)
# 496      981477593  rs11881222                      IFNL3 (PA134952671)
# 498     1444843596  rs11881222                      IFNL3 (PA134952671)
# 558      981477615   rs7248668                      IFNL3 (PA134952671)
# 715     1445206674   rs4803217                      IFNL3 (PA134952671)
#
#                                              DRUG_NAME      PMID  \
# 234  peginterferon alfa-2a (PA164749390),peginterfe...  19749757
# 235  peginterferon alfa-2a (PA164749390),peginterfe...  25769643
# 237  peginterferon alfa-2a (PA164749390),ribavirin ...  21987611
# 238  peginterferon alfa-2a (PA164749390),peginterfe...  29369421
# 239  peginterferon alfa-2a (PA164749390),peginterfe...  19749757
# 241  peginterferon alfa-2a (PA164749390),peginterfe...  21503910
# 242  peginterferon alfa-2a (PA164749390),peginterfe...  21503910
# 243  peginterferon alfa-2a (PA164749390),ribavirin ...  21321200
# 244  peginterferon alfa-2a (PA164749390),peginterfe...  21254157
# 245  peginterferon alfa-2a (PA164749390),peginterfe...  21360545
# 248  peginterferon alfa-2a (PA164749390),ribavirin ...  21321200
# 250  peginterferon alfa-2a (PA164749390),peginterfe...  21048934
# 252  peginterferon alfa-2a (PA164749390),peginterfe...  23142377
# 259  peginterferon alfa-2a (PA164749390),peginterfe...  20648473
# 264  peginterferon alfa-2a (PA164749390),peginterfe...  25278709
# 268  peginterferon alfa-2a (PA164749390),peginterfe...  25393304
# 270  peginterferon alfa-2a (PA164749390),peginterfe...  26075078
# 271  peginterferon alfa-2a (PA164749390),peginterfe...  23281610
# 272  peginterferon alfa-2a (PA164749390),peginterfe...  26003758
# 274  peginterferon alfa-2a (PA164749390),ribavirin ...  21987611
# 275  peginterferon alfa-2a (PA164749390),peginterfe...  26825765
# 280  peginterferon alfa-2a (PA164749390),peginterfe...  26264253
# 281  peginterferon alfa-2a (PA164749390),peginterfe...  25852275
# 283  peginterferon alfa-2a (PA164749390),peginterfe...  31201901
# 303  peginterferon alfa-2a (PA164749390),peginterfe...  19684573
# 304  peginterferon alfa-2a (PA164749390),ribavirin ...  19749757
# 306  peginterferon alfa-2a (PA164749390),peginterfe...  19684573
# 307  peginterferon alfa-2a (PA164749390),peginterfe...  20804372
# 308  peginterferon alfa-2a (PA164749390),peginterfe...  20389235
# 309  peginterferon alfa-2a (PA164749390),ribavirin ...  21606533
# 310  peginterferon alfa-2a (PA164749390),ribavirin ...  21606533
# 311  peginterferon alfa-2a (PA164749390),ribavirin ...  21157362
# 312  peginterferon alfa-2a (PA164749390),peginterfe...  20931559
# 314  peginterferon alfa-2a (PA164749390),peginterfe...  21447862
# 315  peginterferon alfa-2a (PA164749390),peginterfe...  21505315
# 316  peginterferon alfa-2a (PA164749390),peginterfe...  23142377
# 317  peginterferon alfa-2a (PA164749390),peginterfe...  21390311
# 322  peginterferon alfa-2a (PA164749390),peginterfe...  23383658
# 323  peginterferon alfa-2a (PA164749390),ribavirin ...  24748394
# 324  peginterferon alfa-2a (PA164749390),peginterfe...  23490377
# 325  peginterferon alfa-2a (PA164749390),peginterfe...  20648473
# 328  peginterferon alfa-2a (PA164749390),peginterfe...  26098993
# 329  peginterferon alfa-2a (PA164749390),peginterfe...  26032235
# 333  peginterferon alfa-2a (PA164749390),ribavirin ...  21537116
# 336  peginterferon alfa-2a (PA164749390),peginterfe...  25393304
# 341  peginterferon alfa-2a (PA164749390),ribavirin ...  21987611
# 342  peginterferon alfa-2a (PA164749390),ribavirin ...  20728570
# 343  peginterferon alfa-2a (PA164749390),peginterfe...  26284539
# 344  peginterferon alfa-2a (PA164749390),peginterfe...  21572301
# 348  peginterferon alfa-2a (PA164749390),peginterfe...  26339796
# 349  peginterferon alfa-2a (PA164749390),peginterfe...  25958342
# 350  boceprevir (PA165948902),peginterferon alfa-2a...  26670100
# 352  boceprevir (PA165948902),peginterferon alfa-2a...  26191484
# 354  peginterferon alfa-2a (PA164749390),peginterfe...  29369421
# 355  peginterferon alfa-2a (PA164749390),peginterfe...  31201901
# 448  peginterferon alfa-2a (PA164749390),ribavirin ...  19749757
# 496  peginterferon alfa-2a (PA164749390),ribavirin ...  19749757
# 498  peginterferon alfa-2a (PA164749390),peginterfe...  23281610
# 558  peginterferon alfa-2a (PA164749390),ribavirin ...  19749757
# 715  peginterferon alfa-2a (PA164749390),ribavirin ...  26186989
#
#     PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 234           efficacy          yes
# 235           efficacy          yes
# 237           efficacy          yes
# 238           efficacy          yes
# 239           efficacy          yes
# 241           efficacy          yes
# 242           efficacy          yes
# 243           efficacy          yes
# 244           efficacy          yes
# 245           efficacy          yes
# 248           efficacy          yes
# 250           efficacy          yes
# 252           efficacy          yes
# 259           efficacy          yes
# 264           efficacy          yes
# 268           efficacy          yes
# 270           efficacy          yes
# 271           efficacy          yes
# 272           efficacy          yes
# 274           efficacy          yes
# 275           efficacy          yes
# 280           efficacy          yes
# 281           efficacy          yes
# 283           efficacy          yes
# 303           efficacy          yes
# 304           efficacy          yes
# 306           efficacy          yes
# 307           efficacy          yes
# 308           efficacy          yes
# 309           efficacy          yes
# 310           efficacy          yes
# 311           efficacy          yes
# 312           efficacy          yes
# 314           efficacy          yes
# 315           efficacy          yes
# 316           efficacy          yes
# 317           efficacy          yes
# 322           efficacy          yes
# 323           efficacy          yes
# 324           efficacy          yes
# 325           efficacy          yes
# 328           efficacy          yes
# 329           efficacy          yes
# 333           efficacy          yes
# 336           efficacy          yes
# 341           efficacy          yes
# 342           efficacy          yes
# 343           efficacy          yes
# 344           efficacy          yes
# 348           efficacy          yes
# 349           efficacy          yes
# 350           efficacy          yes
# 352           efficacy          yes
# 354           efficacy          yes
# 355           efficacy          yes
# 448           efficacy          yes
# 496           efficacy          yes
# 498           efficacy          yes
# 558           efficacy          yes
# 715           efficacy          yes
#
#                                                  NOTES  \
# 234  This variant is associated with null virologic...
# 235           especially in HCV genotype 1/4 patients.
# 237  This genotype is associated with sustained vir...
# 238  The AA genotype of rs12980275 was found signif...
# 239  This variant is associated with null virologic...
# 241  Treatment was with ribavirin plus peginterfero...
# 242  Treatment was with ribavirin plus peginterfero...
# 243  no GG patients were seen. SVR (at 24 weeks) wa...
# 244  These patients had HCV genotype 2. TT patients...
# 245  Patients had HCV genotypes 2a and 2b. Genotype...
# 248  no GG patients were seen. RVR seen in 83.1% TT...
# 250  The type of peginterferon alfa was not specifi...
# 252  Response was measured by sustained virological...
# 259  This genotype is associated with sustained vir...
# 264  Carriage of the G allele was the best predicto...
# 268  Patients were analyzed by HCV genotype (1,2,3,...
# 270  A multivariate logistic model showed that the ...
# 271  in HCV genotype 2 patients. Subgroup analysis ...
# 272  Egyptian patients with TT genotype showed sign...
# 274  This genotype is associated with sustained vir...
# 275  SVR was achieved in more patients in the IL28B...
# 280         in treatment-naïve patients and relapsers.
# 281  for chronically HCV G2-infected patients who d...
# 283                         only in the allelic model.
# 303  The rs28416813 SNP was found to be highly asso...
# 304  Actually, the associated allele is not stated,...
# 306  A GWAS showed that, in patients of European an...
# 307  The association was with SVR(sustained virolog...
# 308  Patients received peginterferon alpha-2A or 2B...
# 309  These patients had Hepatitis C, genotypes 2 an...
# 310  These patients had Hepatitis C, genotypes 2 an...
# 311  Patients were co-infected with HIV. p listed i...
# 312  The subtype of peginterferon alpha was not spe...
# 314  The peginterferon type was listed only as pegy...
# 315  These patients were also HIV infected. Treatme...
# 316  Response was measured by sustained virological...
# 317  Significantly lower baseline plasma levels of ...
# 322  Genotype CC is associated with higher mean bas...
# 323  Patients were infected with HCV genotype 1 or ...
# 324  Response here refers to sustained virological ...
# 325  This genotype is associated with sustained vir...
# 328  in HCV genotype 1 infected patients. The assoc...
# 329  in HCV-1 infected patients. The association wa...
# 333  This genotype is associated with sustained vir...
# 336  Patients were analyzed by HCV genotype (1,2,3,...
# 341  This genotype is associated with sustained vir...
# 342  This genotype is associated with first phase v...
# 343  IL28B CC genotype was associated with SVR (67%...
# 344  This genotype is associated with sustained vir...
# 348  PEG-interferon alfa (2a and b) was co-adminste...
# 349  in Moroccan patients with hepatitis C virus ge...
# 350  The favorable allele C of rs12979860 was signi...
# 352  in both naïve patients and treatment-experienc...
# 354  The CC genotype of rs12979860 was found signif...
# 355                         only in the allelic model.
# 448  The associated allele is not explicitly stated...
# 496  The associated allele is not explicitly stated...
# 498  in HCV genotype 2 patients using univariate an...
# 558  The associated allele is not explicitly stated...
# 715  in African-American patients. The associations...
#
#                                               SENTENCE ALLELE_PharmGKB  \
# 234  Allele A is associated with increased response...               A
# 235  Genotype AA is associated with increased respo...              AA
# 237  Genotype AA is associated with increased respo...              AA
# 238  Genotype AA is associated with increased respo...              AA
# 239  Allele T is associated with increased response...               T
# 241  Genotype TT is associated with increased respo...              TT
# 242  Genotypes GG + GT are associated with increase...         GG + GT
# 243  Genotype TT is associated with increased respo...              TT
# 244  Genotype TT is associated with increased respo...              TT
# 245  Genotype TT is associated with increased respo...              TT
# 248  Genotype TT is associated with increased respo...              TT
# 250  Genotype TT is associated with increased respo...              TT
# 252  Genotype TT is associated with increased respo...              TT
# 259  Genotype TT is associated with increased respo...              TT
# 264  Genotypes GG + GT is associated with decreased...         GG + GT
# 268  Genotype TT is associated with increased respo...              TT
# 270  Genotype TT is associated with increased respo...              TT
# 271  Genotype TT is associated with increased respo...              TT
# 272  Genotype TT is associated with increased respo...              TT
# 274  Genotype TT is associated with increased respo...              TT
# 275  Allele T is associated with increased response...               T
# 280  Genotype TT is associated with increased respo...              TT
# 281  Genotype TT is associated with increased respo...              TT
# 283  Allele T is associated with increased response...               T
# 303  Allele G is associated with increased response...               G
# 304  Allele C is associated with increased response...               C
# 306  Genotype CC is associated with increased respo...              CC
# 307  Genotype CC is associated with increased respo...              CC
# 308  Genotype CC is associated with increased respo...              CC
# 309  Genotype CC is associated with increased respo...              CC
# 310  Genotypes CC + CT are associated with increase...         CC + CT
# 311  Genotype CC is associated with increased respo...              CC
# 312  Genotype CC is associated with increased respo...              CC
# 314  Genotype CC is associated with increased respo...              CC
# 315  Genotype CC is associated with increased respo...              CC
# 316  Genotype CC is associated with increased respo...              CC
# 317  Genotype CC is associated with increased respo...              CC
# 322  Genotype CC is associated with increased respo...              CC
# 323  Genotype CC is associated with increased respo...              CC
# 324  Genotype CC is associated with increased respo...              CC
# 325  Genotype CC is associated with increased respo...              CC
# 328  Genotype CC is associated with increased respo...              CC
# 329  Genotype TT is associated with increased respo...              TT
# 333  Genotype CC is associated with increased respo...              CC
# 336  Genotype CC is associated with increased respo...              CC
# 341  Genotype CC is associated with increased respo...              CC
# 342  Genotype CC is associated with increased respo...              CC
# 343  Genotype CC is associated with increased respo...              CC
# 344  Genotype CC is associated with increased respo...              CC
# 348  Genotype CC is associated with increased respo...              CC
# 349  Genotype CC is associated with increased respo...              CC
# 350  Allele C is associated with increased response...               C
# 352  Genotype CC is associated with increased respo...              CC
# 354  Genotype CC is associated with increased respo...              CC
# 355  Allele C is associated with increased response...               C
# 448  Allele C is associated with increased response...               C
# 496  Allele G is associated with increased response...               G
# 498  Genotype AA is associated with increased respo...              AA
# 558  Allele A is associated with increased response...               A
# 715  Genotypes AC + CC are associated with increase...         AC + CC
#
#     ALLELE_23andme
# 234              A
# 235              A
# 237              A
# 238              A
# 239              T
# 241              T
# 242              T
# 243              T
# 244              T
# 245              T
# 248              T
# 250              T
# 252              T
# 259              T
# 264              T
# 268              T
# 270              T
# 271              T
# 272              T
# 274              T
# 275              T
# 280              T
# 281              T
# 283              T
# 303              C
# 304              C
# 306              C
# 307              C
# 308              C
# 309              C
# 310              C
# 311              C
# 312              C
# 314              C
# 315              C
# 316              C
# 317              C
# 322              C
# 323              C
# 324              C
# 325              C
# 328              C
# 329              C
# 333              C
# 336              C
# 341              C
# 342              C
# 343              C
# 344              C
# 348              C
# 349              C
# 350              C
# 352              C
# 354              C
# 355              C
# 448              T
# 496              A
# 498              A
# 558              G
# 715              C

# %% [markdown]
# ## With this information, we should expect some larger numbers than expected

# %%
# Separate multiple entries by converting them to a list
sanity_free = ec_merged.copy(deep = True)
sanity_free.GENE_SYMBOL = sanity_free.GENE_SYMBOL.str.split(',')
sanity_free.DRUG_NAME = sanity_free.DRUG_NAME.str.split(',')

# %% [markdown]
# Take those newly created lists and `explode` them into individual
# rows, like what we saw in the SQL homework.

# %%
clean_explosion = sanity_free.explode('DRUG_NAME')\
    .reset_index(drop=True)\
    .explode('GENE_SYMBOL')\
    .reset_index(drop=True)

# %%
# Isolate our conditions with single item columns
check_goi = clean_explosion.GENE_SYMBOL.str.contains(goi, regex=False)
check_doi = clean_explosion.DRUG_NAME.str.contains(doi, regex=False)
explode_check = clean_explosion[(check_goi) & (check_doi)]
display(explode_check)
print(f'Number of associations: {explode_check.shape[0]}')
# Out:
#       Annotation_ID    dbSNP_ID          GENE_SYMBOL  \
# 338       769248374  rs12980275  IFNL3 (PA134952671)
# 341      1444843603  rs12980275  IFNL3 (PA134952671)
# 346      1444705811  rs12980275  IFNL3 (PA134952671)
# 348      1449164615  rs12980275  IFNL3 (PA134952671)
# 350       769248378   rs8099917  IFNL3 (PA134952671)
# 355       981479632   rs8099917  IFNL3 (PA134952671)
# 358       981479639   rs8099917  IFNL3 (PA134952671)
# 361       981481554   rs8099917  IFNL3 (PA134952671)
# 363       981481567   rs8099917  IFNL3 (PA134952671)
# 366       981483529   rs8099917  IFNL3 (PA134952671)
# 372       981481560   rs8099917  IFNL3 (PA134952671)
# 377       981481540   rs8099917  IFNL3 (PA134952671)
# 382       981934519   rs8099917  IFNL3 (PA134952671)
# 399      1444704847   rs8099917  IFNL3 (PA134952671)
# 411      1445296808   rs8099917  IFNL3 (PA134952671)
# 422      1444665876   rs8099917  IFNL3 (PA134952671)
# 431      1444843486   rs8099917  IFNL3 (PA134952671)
# 434      1444843578   rs8099917  IFNL3 (PA134952671)
# 437      1444843741   rs8099917  IFNL3 (PA134952671)
# 442      1444705817   rs8099917  IFNL3 (PA134952671)
# 444      1447682270   rs8099917  IFNL3 (PA134952671)
# 455      1447676770   rs8099917  IFNL3 (PA134952671)
# 459      1447676959   rs8099917  IFNL3 (PA134952671)
# 464      1450810272   rs8099917  IFNL3 (PA134952671)
# 498       769250998  rs28416813  IFNL3 (PA134952671)
# 501       981477606  rs28416813  IFNL3 (PA134952671)
# 505       769251002  rs12979860  IFNL3 (PA134952671)
# 511       981481472  rs12979860  IFNL3 (PA134952671)
# 517       981501391  rs12979860  IFNL3 (PA134952671)
# 523       981478958  rs12979860  IFNL3 (PA134952671)
# 527       981478966  rs12979860  IFNL3 (PA134952671)
# 531       981483535  rs12979860  IFNL3 (PA134952671)
# 535       981481534  rs12979860  IFNL3 (PA134952671)
# 547       981481546  rs12979860  IFNL3 (PA134952671)
# 553       981478976  rs12979860  IFNL3 (PA134952671)
# 559       981934499  rs12979860  IFNL3 (PA134952671)
# 565       982031571  rs12979860  IFNL3 (PA134952671)
# 591      1448107049  rs12979860  IFNL3 (PA134952671)
# 597      1184985914  rs12979860  IFNL3 (PA134952671)
# 601      1448107024  rs12979860  IFNL3 (PA134952671)
# 607      1444704894  rs12979860  IFNL3 (PA134952671)
# 623      1444843627  rs12979860  IFNL3 (PA134952671)
# 629      1444843642  rs12979860  IFNL3 (PA134952671)
# 653      1444706170  rs12979860  IFNL3 (PA134952671)
# 665      1444665865  rs12979860  IFNL3 (PA134952671)
# 695      1444705804  rs12979860  IFNL3 (PA134952671)
# 699      1444706036  rs12979860  IFNL3 (PA134952671)
# 703      1447676759  rs12979860  IFNL3 (PA134952671)
# 709      1444706780  rs12979860  IFNL3 (PA134952671)
# 727      1446904199  rs12979860  IFNL3 (PA134952671)
# 731      1447676885  rs12979860  IFNL3 (PA134952671)
# 739      1447682452  rs12979860  IFNL3 (PA134952671)
# 753      1447676829  rs12979860  IFNL3 (PA134952671)
# 765      1449164359  rs12979860  IFNL3 (PA134952671)
# 769      1450810253  rs12979860  IFNL3 (PA134952671)
# 928       981477583   rs8105790  IFNL3 (PA134952671)
# 993       981477593  rs11881222  IFNL3 (PA134952671)
# 997      1444843596  rs11881222  IFNL3 (PA134952671)
# 1093      981477615   rs7248668  IFNL3 (PA134952671)
# 1315     1445206674   rs4803217  IFNL3 (PA134952671)
#
#                                 DRUG_NAME      PMID PHENOTYPE_CATEGORY  \
# 338   peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 341   peginterferon alfa-2a (PA164749390)  25769643           efficacy
# 346   peginterferon alfa-2a (PA164749390)  21987611           efficacy
# 348   peginterferon alfa-2a (PA164749390)  29369421           efficacy
# 350   peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 355   peginterferon alfa-2a (PA164749390)  21503910           efficacy
# 358   peginterferon alfa-2a (PA164749390)  21503910           efficacy
# 361   peginterferon alfa-2a (PA164749390)  21321200           efficacy
# 363   peginterferon alfa-2a (PA164749390)  21254157           efficacy
# 366   peginterferon alfa-2a (PA164749390)  21360545           efficacy
# 372   peginterferon alfa-2a (PA164749390)  21321200           efficacy
# 377   peginterferon alfa-2a (PA164749390)  21048934           efficacy
# 382   peginterferon alfa-2a (PA164749390)  23142377           efficacy
# 399   peginterferon alfa-2a (PA164749390)  20648473           efficacy
# 411   peginterferon alfa-2a (PA164749390)  25278709           efficacy
# 422   peginterferon alfa-2a (PA164749390)  25393304           efficacy
# 431   peginterferon alfa-2a (PA164749390)  26075078           efficacy
# 434   peginterferon alfa-2a (PA164749390)  23281610           efficacy
# 437   peginterferon alfa-2a (PA164749390)  26003758           efficacy
# 442   peginterferon alfa-2a (PA164749390)  21987611           efficacy
# 444   peginterferon alfa-2a (PA164749390)  26825765           efficacy
# 455   peginterferon alfa-2a (PA164749390)  26264253           efficacy
# 459   peginterferon alfa-2a (PA164749390)  25852275           efficacy
# 464   peginterferon alfa-2a (PA164749390)  31201901           efficacy
# 498   peginterferon alfa-2a (PA164749390)  19684573           efficacy
# 501   peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 505   peginterferon alfa-2a (PA164749390)  19684573           efficacy
# 511   peginterferon alfa-2a (PA164749390)  20804372           efficacy
# 517   peginterferon alfa-2a (PA164749390)  20389235           efficacy
# 523   peginterferon alfa-2a (PA164749390)  21606533           efficacy
# 527   peginterferon alfa-2a (PA164749390)  21606533           efficacy
# 531   peginterferon alfa-2a (PA164749390)  21157362           efficacy
# 535   peginterferon alfa-2a (PA164749390)  20931559           efficacy
# 547   peginterferon alfa-2a (PA164749390)  21447862           efficacy
# 553   peginterferon alfa-2a (PA164749390)  21505315           efficacy
# 559   peginterferon alfa-2a (PA164749390)  23142377           efficacy
# 565   peginterferon alfa-2a (PA164749390)  21390311           efficacy
# 591   peginterferon alfa-2a (PA164749390)  23383658           efficacy
# 597   peginterferon alfa-2a (PA164749390)  24748394           efficacy
# 601   peginterferon alfa-2a (PA164749390)  23490377           efficacy
# 607   peginterferon alfa-2a (PA164749390)  20648473           efficacy
# 623   peginterferon alfa-2a (PA164749390)  26098993           efficacy
# 629   peginterferon alfa-2a (PA164749390)  26032235           efficacy
# 653   peginterferon alfa-2a (PA164749390)  21537116           efficacy
# 665   peginterferon alfa-2a (PA164749390)  25393304           efficacy
# 695   peginterferon alfa-2a (PA164749390)  21987611           efficacy
# 699   peginterferon alfa-2a (PA164749390)  20728570           efficacy
# 703   peginterferon alfa-2a (PA164749390)  26284539           efficacy
# 709   peginterferon alfa-2a (PA164749390)  21572301           efficacy
# 727   peginterferon alfa-2a (PA164749390)  26339796           efficacy
# 731   peginterferon alfa-2a (PA164749390)  25958342           efficacy
# 739   peginterferon alfa-2a (PA164749390)  26670100           efficacy
# 753   peginterferon alfa-2a (PA164749390)  26191484           efficacy
# 765   peginterferon alfa-2a (PA164749390)  29369421           efficacy
# 769   peginterferon alfa-2a (PA164749390)  31201901           efficacy
# 928   peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 993   peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 997   peginterferon alfa-2a (PA164749390)  23281610           efficacy
# 1093  peginterferon alfa-2a (PA164749390)  19749757           efficacy
# 1315  peginterferon alfa-2a (PA164749390)  26186989           efficacy
#
#      SIGNIFICANCE                                              NOTES  \
# 338           yes  This variant is associated with null virologic...
# 341           yes           especially in HCV genotype 1/4 patients.
# 346           yes  This genotype is associated with sustained vir...
# 348           yes  The AA genotype of rs12980275 was found signif...
# 350           yes  This variant is associated with null virologic...
# 355           yes  Treatment was with ribavirin plus peginterfero...
# 358           yes  Treatment was with ribavirin plus peginterfero...
# 361           yes  no GG patients were seen. SVR (at 24 weeks) wa...
# 363           yes  These patients had HCV genotype 2. TT patients...
# 366           yes  Patients had HCV genotypes 2a and 2b. Genotype...
# 372           yes  no GG patients were seen. RVR seen in 83.1% TT...
# 377           yes  The type of peginterferon alfa was not specifi...
# 382           yes  Response was measured by sustained virological...
# 399           yes  This genotype is associated with sustained vir...
# 411           yes  Carriage of the G allele was the best predicto...
# 422           yes  Patients were analyzed by HCV genotype (1,2,3,...
# 431           yes  A multivariate logistic model showed that the ...
# 434           yes  in HCV genotype 2 patients. Subgroup analysis ...
# 437           yes  Egyptian patients with TT genotype showed sign...
# 442           yes  This genotype is associated with sustained vir...
# 444           yes  SVR was achieved in more patients in the IL28B...
# 455           yes         in treatment-naïve patients and relapsers.
# 459           yes  for chronically HCV G2-infected patients who d...
# 464           yes                         only in the allelic model.
# 498           yes  The rs28416813 SNP was found to be highly asso...
# 501           yes  Actually, the associated allele is not stated,...
# 505           yes  A GWAS showed that, in patients of European an...
# 511           yes  The association was with SVR(sustained virolog...
# 517           yes  Patients received peginterferon alpha-2A or 2B...
# 523           yes  These patients had Hepatitis C, genotypes 2 an...
# 527           yes  These patients had Hepatitis C, genotypes 2 an...
# 531           yes  Patients were co-infected with HIV. p listed i...
# 535           yes  The subtype of peginterferon alpha was not spe...
# 547           yes  The peginterferon type was listed only as pegy...
# 553           yes  These patients were also HIV infected. Treatme...
# 559           yes  Response was measured by sustained virological...
# 565           yes  Significantly lower baseline plasma levels of ...
# 591           yes  Genotype CC is associated with higher mean bas...
# 597           yes  Patients were infected with HCV genotype 1 or ...
# 601           yes  Response here refers to sustained virological ...
# 607           yes  This genotype is associated with sustained vir...
# 623           yes  in HCV genotype 1 infected patients. The assoc...
# 629           yes  in HCV-1 infected patients. The association wa...
# 653           yes  This genotype is associated with sustained vir...
# 665           yes  Patients were analyzed by HCV genotype (1,2,3,...
# 695           yes  This genotype is associated with sustained vir...
# 699           yes  This genotype is associated with first phase v...
# 703           yes  IL28B CC genotype was associated with SVR (67%...
# 709           yes  This genotype is associated with sustained vir...
# 727           yes  PEG-interferon alfa (2a and b) was co-adminste...
# 731           yes  in Moroccan patients with hepatitis C virus ge...
# 739           yes  The favorable allele C of rs12979860 was signi...
# 753           yes  in both naïve patients and treatment-experienc...
# 765           yes  The CC genotype of rs12979860 was found signif...
# 769           yes                         only in the allelic model.
# 928           yes  The associated allele is not explicitly stated...
# 993           yes  The associated allele is not explicitly stated...
# 997           yes  in HCV genotype 2 patients using univariate an...
# 1093          yes  The associated allele is not explicitly stated...
# 1315          yes  in African-American patients. The associations...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 338   Allele A is associated with increased response...               A
# 341   Genotype AA is associated with increased respo...              AA
# 346   Genotype AA is associated with increased respo...              AA
# 348   Genotype AA is associated with increased respo...              AA
# 350   Allele T is associated with increased response...               T
# 355   Genotype TT is associated with increased respo...              TT
# 358   Genotypes GG + GT are associated with increase...         GG + GT
# 361   Genotype TT is associated with increased respo...              TT
# 363   Genotype TT is associated with increased respo...              TT
# 366   Genotype TT is associated with increased respo...              TT
# 372   Genotype TT is associated with increased respo...              TT
# 377   Genotype TT is associated with increased respo...              TT
# 382   Genotype TT is associated with increased respo...              TT
# 399   Genotype TT is associated with increased respo...              TT
# 411   Genotypes GG + GT is associated with decreased...         GG + GT
# 422   Genotype TT is associated with increased respo...              TT
# 431   Genotype TT is associated with increased respo...              TT
# 434   Genotype TT is associated with increased respo...              TT
# 437   Genotype TT is associated with increased respo...              TT
# 442   Genotype TT is associated with increased respo...              TT
# 444   Allele T is associated with increased response...               T
# 455   Genotype TT is associated with increased respo...              TT
# 459   Genotype TT is associated with increased respo...              TT
# 464   Allele T is associated with increased response...               T
# 498   Allele G is associated with increased response...               G
# 501   Allele C is associated with increased response...               C
# 505   Genotype CC is associated with increased respo...              CC
# 511   Genotype CC is associated with increased respo...              CC
# 517   Genotype CC is associated with increased respo...              CC
# 523   Genotype CC is associated with increased respo...              CC
# 527   Genotypes CC + CT are associated with increase...         CC + CT
# 531   Genotype CC is associated with increased respo...              CC
# 535   Genotype CC is associated with increased respo...              CC
# 547   Genotype CC is associated with increased respo...              CC
# 553   Genotype CC is associated with increased respo...              CC
# 559   Genotype CC is associated with increased respo...              CC
# 565   Genotype CC is associated with increased respo...              CC
# 591   Genotype CC is associated with increased respo...              CC
# 597   Genotype CC is associated with increased respo...              CC
# 601   Genotype CC is associated with increased respo...              CC
# 607   Genotype CC is associated with increased respo...              CC
# 623   Genotype CC is associated with increased respo...              CC
# 629   Genotype TT is associated with increased respo...              TT
# 653   Genotype CC is associated with increased respo...              CC
# 665   Genotype CC is associated with increased respo...              CC
# 695   Genotype CC is associated with increased respo...              CC
# 699   Genotype CC is associated with increased respo...              CC
# 703   Genotype CC is associated with increased respo...              CC
# 709   Genotype CC is associated with increased respo...              CC
# 727   Genotype CC is associated with increased respo...              CC
# 731   Genotype CC is associated with increased respo...              CC
# 739   Allele C is associated with increased response...               C
# 753   Genotype CC is associated with increased respo...              CC
# 765   Genotype CC is associated with increased respo...              CC
# 769   Allele C is associated with increased response...               C
# 928   Allele C is associated with increased response...               C
# 993   Allele G is associated with increased response...               G
# 997   Genotype AA is associated with increased respo...              AA
# 1093  Allele A is associated with increased response...               A
# 1315  Genotypes AC + CC are associated with increase...         AC + CC
#
#      ALLELE_23andme
# 338               A
# 341               A
# 346               A
# 348               A
# 350               T
# 355               T
# 358               T
# 361               T
# 363               T
# 366               T
# 372               T
# 377               T
# 382               T
# 399               T
# 411               T
# 422               T
# 431               T
# 434               T
# 437               T
# 442               T
# 444               T
# 455               T
# 459               T
# 464               T
# 498               C
# 501               C
# 505               C
# 511               C
# 517               C
# 523               C
# 527               C
# 531               C
# 535               C
# 547               C
# 553               C
# 559               C
# 565               C
# 591               C
# 597               C
# 601               C
# 607               C
# 623               C
# 629               C
# 653               C
# 665               C
# 695               C
# 699               C
# 703               C
# 709               C
# 727               C
# 731               C
# 739               C
# 753               C
# 765               C
# 769               C
# 928               T
# 993               A
# 997               A
# 1093              G
# 1315              C
# Number of associations: 60

# %% [markdown]
# ## Final part: Grouping and aggregation

# %%
cols_of_interest = ['GENE_SYMBOL', 'DRUG_NAME', 'dbSNP_ID']
final_ec = clean_explosion.loc[:,cols_of_interest].groupby(['DRUG_NAME', 'GENE_SYMBOL'], as_index = False).aggregate(';'.join)

# %%
# Uncomment to write to file (if that's your thing)
# final_ec.to_csv('ec_dbSNPS.tsv', sep = '\t')

# %% [markdown]
# With all of our sanity checks, we should end up with a single entry that summarizes
# all the conditions shown above instead of a multiple entries. This means that every
# gene/drug combo seen in this dataset should have one and only one entry in this
# summarized DataFrame.

# %%
final_goi = final_ec.GENE_SYMBOL == goi
final_doi = final_ec.DRUG_NAME == doi
final_check = final_ec[(final_goi) & (final_doi)]
print(f'Gene of interest:        {goi}')
print(f'Drug of interest:        {doi}')
print(f'Total associated dbSNPs: {final_check.dbSNP_ID.str.count(";").values[0] + 1}')
display(final_check)
# Out:
# Gene of interest:        IFNL3 (PA134952671)
# Drug of interest:        peginterferon alfa-2a (PA164749390)
# Total associated dbSNPs: 60
#                                DRUG_NAME          GENE_SYMBOL  \
# 710  peginterferon alfa-2a (PA164749390)  IFNL3 (PA134952671)
#
#                                               dbSNP_ID
# 710  rs12980275;rs12980275;rs12980275;rs12980275;rs...
